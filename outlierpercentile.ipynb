# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("/content/sample_data/heights.csv")
print(dataset)
p = np.percentile(dataset.height, [5, 95])
print(p)
new_def = dataset[(dataset['height'] > p[0]) & (dataset['height'] < p[1])]
print(new_def)
# Out:
#        name  height
# 0       Ali     5.9
# 1     Awais     5.2
# 2      Sara     5.1
# 3    Ayesha     5.5
# 4   Mehwish     4.9
# 5      Raza     5.4
# 6    Safdar     6.2
# 7   Ahtsham     6.5
# 8    Binish     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11      Zia     5.6
# 12   yousof     1.2
# 13     Iqra     5.5
# [3.605 9.69 ]
#        name  height
# 0       Ali     5.9
# 1     Awais     5.2
# 2      Sara     5.1
# 3    Ayesha     5.5
# 4   Mehwish     4.9
# 5      Raza     5.4
# 6    Safdar     6.2
# 7   Ahtsham     6.5
# 8    Binish     7.1
# 10     jose     6.1
# 11      Zia     5.6
# 13     Iqra     5.5

# %%
int(9.3)
# Out:
# 9

# %%
os.getcwd()
# Out:
# '/content'
